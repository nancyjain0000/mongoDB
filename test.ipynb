# %%
from pymongo import MongoClient

# %%
uri = "mongodb+srv://nancyjain0000:9991255661@cluster0.py6fqmp.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#creating a data base
mydb=client["mydatabase"]

# %%
#listing all the databases name
client.list_database_names()
# Out:
# ['mydatabase', 'admin', 'local']

# %%
#creating a collection
mycol=mydb['myfirstcollection']

# %%
myfirstrecord={"first name":"nancy","last name":"jain","address":"dharuhera"}

# %%
myfirstrecord
# Out:
# {'first name': 'nancy', 'last name': 'jain', 'address': 'dharuhera'}

# %%
mycol.insert_one(myfirstrecord)

# %%
mysecondrecord={"first name":"sanjana","last name":"jain","address":"dharuhera"}

# %%
mycol.insert_one(mysecondrecord)

# %%
mythirdrecord={"first name":"sanjay","last name":"jain","address":"dharuhera","salary":10000000}
mycol.insert_one(mythirdrecord)

# %%
multiplerecords=[
    {"first name":"yash","last name":"jain","address":"dharuhera","salary":800000},
    {"first name":"anil","last name":"jain","address":"dharuhera","salary":600000},
    {"first name":"seema","last name":"jain","address":"dharuhera","salary":30000},
    {"first name":"aashi","last name":"jain","address":"dharuhera","salary":10000},
    {"first name":"aman","last name":"jain","address":"dharuhera","salary":200000}
]

# %%
mycol.insert_many(multiplerecords)

# %%
multiplerecord=[
    {"first name":"pooja","last name":"jain","address":"dharuhera","salary":8000},
    {"first name":"subhash","last name":"jain","address":"dharuhera","salary":60000}
]

# %%
x=mycol.insert_many(multiplerecord)

# %%
x.inserted_ids
# Out:
# [ObjectId('651867c538e6727c4256a929'), ObjectId('651867c538e6727c4256a92a')]

# %%
#to create a custom id
multiplerecord=[
    {"__id":1,"first name":"manshi","last name":"sharma","address":"dharuhera","salary":80000},
    {"__id":2,"first name":"tanvi","last name":"sharma","address":"dharuhera","salary":600000}
]

# %%
mycol.insert_many(multiplerecord)

# %%
#find the record
mycol.find_one()
# Out:
# {'_id': ObjectId('651867c338e6727c4256a921'),
#  'first name': 'nancy',
#  'last name': 'jain',
#  'address': 'dharuhera'}

# %%
#to fetch multiple records
for x in mycol.find():
    print(x)
# Out:
# {'_id': ObjectId('651867c338e6727c4256a921'), 'first name': 'nancy', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c438e6727c4256a922'), 'first name': 'sanjana', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c438e6727c4256a923'), 'first name': 'sanjay', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000000}
# {'_id': ObjectId('651867c438e6727c4256a924'), 'first name': 'yash', 'last name': 'jain', 'address': 'dharuhera', 'salary': 800000}
# {'_id': ObjectId('651867c438e6727c4256a925'), 'first name': 'anil', 'last name': 'jain', 'address': 'dharuhera', 'salary': 600000}
# {'_id': ObjectId('651867c438e6727c4256a926'), 'first name': 'seema', 'last name': 'jain', 'address': 'dharuhera', 'salary': 30000}
# {'_id': ObjectId('651867c438e6727c4256a927'), 'first name': 'aashi', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000}
# ...

# %%
mycol.find_one({"salary":60000})
# Out:
# {'_id': ObjectId('651867c538e6727c4256a92a'),
#  'first name': 'subhash',
#  'last name': 'jain',
#  'address': 'dharuhera',
#  'salary': 60000}

# %%
for x in mycol.find({"first name":"nancy"}):
    print(x)
# Out:
# {'_id': ObjectId('651867c338e6727c4256a921'), 'first name': 'nancy', 'last name': 'jain', 'address': 'dharuhera'}

# %%
#sorting operation in ascending order
for x in mycol.find().sort("first name"):
    print(x)
# Out:
# {'_id': ObjectId('651867c438e6727c4256a927'), 'first name': 'aashi', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000}
# {'_id': ObjectId('651867c438e6727c4256a928'), 'first name': 'aman', 'last name': 'jain', 'address': 'dharuhera', 'salary': 200000}
# {'_id': ObjectId('651867c438e6727c4256a925'), 'first name': 'anil', 'last name': 'jain', 'address': 'dharuhera', 'salary': 600000}
# {'_id': ObjectId('651867c538e6727c4256a92b'), '__id': 1, 'first name': 'manshi', 'last name': 'sharma', 'address': 'dharuhera', 'salary': 80000}
# {'_id': ObjectId('651867c338e6727c4256a921'), 'first name': 'nancy', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c538e6727c4256a929'), 'first name': 'pooja', 'last name': 'jain', 'address': 'dharuhera', 'salary': 8000}
# {'_id': ObjectId('651867c438e6727c4256a922'), 'first name': 'sanjana', 'last name': 'jain', 'address': 'dharuhera'}
# ...

# %%
#sorting operation in descending order
for x in mycol.find().sort("first name",-1):
    print(x)
# Out:
# {'_id': ObjectId('651867c438e6727c4256a924'), 'first name': 'yash', 'last name': 'jain', 'address': 'dharuhera', 'salary': 800000}
# {'_id': ObjectId('651867c538e6727c4256a92c'), '__id': 2, 'first name': 'tanvi', 'last name': 'sharma', 'address': 'dharuhera', 'salary': 600000}
# {'_id': ObjectId('651867c538e6727c4256a92a'), 'first name': 'subhash', 'last name': 'jain', 'address': 'dharuhera', 'salary': 60000}
# {'_id': ObjectId('651867c438e6727c4256a926'), 'first name': 'seema', 'last name': 'jain', 'address': 'dharuhera', 'salary': 30000}
# {'_id': ObjectId('651867c438e6727c4256a923'), 'first name': 'sanjay', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000000}
# {'_id': ObjectId('651867c438e6727c4256a922'), 'first name': 'sanjana', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c538e6727c4256a929'), 'first name': 'pooja', 'last name': 'jain', 'address': 'dharuhera', 'salary': 8000}
# ...

# %%
#delete record
mycol.delete_one({"first name":"nancy"})

# %%
#sorting operation in descending order
for x in mycol.find().sort("first name",-1):
    print(x)
# Out:
# {'_id': ObjectId('651867c438e6727c4256a924'), 'first name': 'yash', 'last name': 'jain', 'address': 'dharuhera', 'salary': 800000}
# {'_id': ObjectId('651867c538e6727c4256a92c'), '__id': 2, 'first name': 'tanvi', 'last name': 'sharma', 'address': 'dharuhera', 'salary': 600000}
# {'_id': ObjectId('651867c538e6727c4256a92a'), 'first name': 'subhash', 'last name': 'jain', 'address': 'dharuhera', 'salary': 60000}
# {'_id': ObjectId('651867c438e6727c4256a926'), 'first name': 'seema', 'last name': 'jain', 'address': 'dharuhera', 'salary': 30000}
# {'_id': ObjectId('651867c438e6727c4256a923'), 'first name': 'sanjay', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000000}
# {'_id': ObjectId('651867c438e6727c4256a922'), 'first name': 'sanjana', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c538e6727c4256a929'), 'first name': 'pooja', 'last name': 'jain', 'address': 'dharuhera', 'salary': 8000}
# ...

# %%
mycol.delete_many({"first name":"yash"})

# %%
mycol.delete_many({"first name":"subhash"})

# %%
mycol.delete_many({"first name":"aashi"})

# %%
#sorting operation in descending order
for x in mycol.find().sort("first name",-1):
    print(x)
# Out:
# {'_id': ObjectId('651867c538e6727c4256a92c'), '__id': 2, 'first name': 'tanvi', 'last name': 'sharma', 'address': 'dharuhera', 'salary': 600000}
# {'_id': ObjectId('651867c438e6727c4256a926'), 'first name': 'seema', 'last name': 'jain', 'address': 'dharuhera', 'salary': 30000}
# {'_id': ObjectId('651867c438e6727c4256a923'), 'first name': 'sanjay', 'last name': 'jain', 'address': 'dharuhera', 'salary': 10000000}
# {'_id': ObjectId('651867c438e6727c4256a922'), 'first name': 'sanjana', 'last name': 'jain', 'address': 'dharuhera'}
# {'_id': ObjectId('651867c538e6727c4256a929'), 'first name': 'pooja', 'last name': 'jain', 'address': 'dharuhera', 'salary': 8000}
# {'_id': ObjectId('651867c538e6727c4256a92b'), '__id': 1, 'first name': 'manshi', 'last name': 'sharma', 'address': 'dharuhera', 'salary': 80000}
# {'_id': ObjectId('651867c438e6727c4256a925'), 'first name': 'anil', 'last name': 'jain', 'address': 'dharuhera', 'salary': 600000}
# ...

# %%
#deleting all the record
mycol.delete_many({})

# %%
#limit function
for x in mycol.find().limit(4):
    print(x)

# %%
myquery={"first name":"tanvi"}
newvalue={"$set":{"first name":"nancy"}}

# %%
#update the record
mycol.update_one(myquery,newvalue)

# %%
for x in mycol.find():
    print(x)

# %%
#checking of the condition
for x in mycol.find({"salary":{"$lt":600000}}):
    print(x)

# %%
#deleting all the record
mycol.delete_many({})

# %%
for x in mycol.find():
    print(x)

# %%
import pandas as pd

# %%
df=pd.read_csv("E:\iNeauron\MongoDB\googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 13

# %%
#creating new collection
mycol2=mydb["googleplaystore"]

# %%
import json
list(json.loads(df.T.to_json()).values())
# Out:
# [{'App': 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': '159',
#   'Size': '19M',
#   'Installs': '10,000+',
#   'Type': 'Free',
#   'Price': '0',
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last Updated': 'January 7, 2018',
#   'Current Ver': '1.0.0',
#   'Android Ver': '4.0.3 and up'},
#  {'App': 'Coloring book moana',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.9,
#   'Reviews': '967',
#   'Size': '14M',
#   'Installs': '500,000+',
#   'Type': 'Free',
#   'Price': '0',
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design;Pretend Play',
#   'Last Updated': 'January 15, 2018',
#   'Current Ver': '2.0.0',
#   'Android Ver': '4.0.3 and up'},
#  {'App': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': '87510',
#   'Size': '8.7M',
#   'Installs': '5,000,000+',
#   'Type': 'Free',
#   'Price': '0',
# ...

# %%
mycsvfile=list(json.loads(df.T.to_json()).values())
mycol2.insert_many(mycsvfile)
